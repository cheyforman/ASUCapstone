# %%
CI


observed_infections = np.array([
    772, 47, 831, 264, 4080, 422, 408, 221, 86, 2091, 1120, 198, 144, 1400, 716,
    304, 247, 558, 514, 116, 819, 1245, 1118, 626, 286, 864, 82, 258, 236, 157,
    899, 291, 2618, 1045, 59, 1715, 374, 399, 1856, 67, 428, 94, 555, 2373, 270,
    100, 522, 807, 387, 652, 38
])
hospitals_reporting = np.array([
    88, 10, 71, 52, 334, 58, 32, 8, 9, 223, 109, 17, 17, 130, 93, 38, 60, 69,
    103, 18, 46, 68, 98, 50, 64, 74, 12, 28, 28, 13, 70, 31, 173, 104, 9, 146,
    86, 35, 177, 10, 64, 18, 101, 365, 38, 6, 81, 55, 28, 86, 11
])


X = observed_infections.reshape(-1, 1)
y = hospitals_reporting


model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

r2 = r2_score(y, y_pred)

print(f"R² score: {r2:.2f}")



plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Observed Data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression Line')
plt.title('Prediction of CDI Cases from Number of Acute Care Hospitals')
plt.xlabel('Observed CDI Infections')
plt.ylabel('No. of Acute Care Hospitals Reporting CDI')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# R² score: 0.84

# %%
observed_infections = np.array([
  225,5,142,102,683,70,70,35,29,668,292,25,
    9,238,134,58,31,198,187,25,111,192,244,64,
    101,203,14,38,69,22,198,29,640,333,15,399,116,76,
    383,27,178,17,306,617,37,13,159,116,89,64,2
])
hospitals_reporting = np.array([88,10
,71
,52
,339
,58
,32
,8
,9
,223
,109
,17
,17
,130
,93
,38
,60
,69
,103
,18
,46
,68
,98
,50
,64
,74
,12
,28
,28
,13
,70
,31
,172
,104
,9
,145
,86
,35
,177
,10
,64
,18
,101
,366
,38
,6
,80
,55
,28
,86
,11

])


X = observed_infections.reshape(-1, 1)
y = hospitals_reporting


model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

r2 = r2_score(y, y_pred)

print(f"R² score: {r2:.2f}")



plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Observed Data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression Line')
plt.title('Prediction of MRSA Cases from Number of Acute Care Hospitals')
plt.xlabel('Observed MRSA Infections')
plt.ylabel('No. of Acute Care Hospitals Reporting MRSA')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# R² score: 0.85
